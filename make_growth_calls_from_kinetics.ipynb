# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt

# %% [markdown]
# Read in web processed data

# %%
plates = pd.read_csv('Data/plate_datatype.csv')
kinetics = pd.read_csv('Data/kinetic_datatype.csv')
summary = pd.read_csv('Data/summary_table.csv')

# %%
wells_with_negative_controls = ['PM01','PM02A','PM03B','PM04A','PM05','PM06','PM07','PM08']
wells_with_positive_controls = ['PM05']

# %% [markdown]
# Ensure naming for strains are consistent to avoid errors during replicate grouping

# %%
plate_strains = kinetics[['Strain','Plate']].drop_duplicates().groupby('Plate')['Strain'].unique()

for plate, strains in plate_strains.items():
    print(f"{plate}: {', '.join(strains)}")
# Out:
# PM01: BW25113, MS5762, MS8806, yfdF, yhjE, ypjC, yqeG
# PM02A: argF, argH, BW25113, BW25113wt, malE, MS5762, MS8806, yfdF, yhjE, ypjC, yqeG
# PM05: BW25113wt, hisJ
# PM09: BW25113, BW25113WT, dedA, yahO, ycaC, ydfR, ygaM, ygaY, yiaG, yjjU, yjjV, ynfN, yodC
# PM10: BW25113, BW25113WT, dedA, yahO, ycaC, ydfR, ydgD, ygaM, yiaG, yjjU, yjjV, ynfN, yodC
# PM11C: appY, BW25113, gnsB, wbbK, yahO, ycaC, ydcD, ygaM, yiaG
# PM12B: appY, BW25113, gnsB, wbbK, ydcD, ydjM, yebF, yebG

# %%
kinetics[(kinetics['Strain']=='BW25113wt')&(kinetics['Plate']=='PM02A')]

kinetics['kinetics'] = df['column_name'].replace('B', 'A')
# Out:
#      PlateIDs     Strain   Specie Well  Plate         Media Replicates  \
# 9408    ECP98  BW25113wt  E. coli  A01  PM02A  M9 No Carbon         R1
# 9409    ECP98  BW25113wt  E. coli  A02  PM02A  M9 No Carbon         R1
# 9410    ECP98  BW25113wt  E. coli  A03  PM02A  M9 No Carbon         R1
# 9411    ECP98  BW25113wt  E. coli  A04  PM02A  M9 No Carbon         R1
# 9412    ECP98  BW25113wt  E. coli  A05  PM02A  M9 No Carbon         R1
# ...       ...        ...      ...  ...    ...           ...        ...
# 9595    ECP99  BW25113wt  E. coli  H08  PM02A  M9 No Carbon         R2
# 9596    ECP99  BW25113wt  E. coli  H09  PM02A  M9 No Carbon         R2
# 9597    ECP99  BW25113wt  E. coli  H10  PM02A  M9 No Carbon         R2
# 9598    ECP99  BW25113wt  E. coli  H11  PM02A  M9 No Carbon         R2
# 9599    ECP99  BW25113wt  E. coli  H12  PM02A  M9 No Carbon         R2
#
#                    Compound                 Description KEGG ID  \
# 9408       Negative Control  C-Source, negative control     NaN
# 9409  Chondroitin Sulfate C           C-Source, polymer  C00635
# 9410         a-Cyclodextrin           C-Source, polymer  C00973
# 9411         b-Cyclodextrin           C-Source, polymer     NaN
# 9412         g-Cyclodextrin           C-Source, polymer     NaN
# ...                     ...                         ...     ...
# 9595             Putrescine             C-Source, amine  C00134
# 9596       Dihydroxyacetone           C-Source, alcohol  C00184
# 9597         2,3-Butanediol           C-Source, alcohol  C03044
# 9598        2,3-Butanedione           C-Source, alcohol  C00741
# 9599   3-Hydroxy-2-butanone           C-Source, alcohol  C00466
#
#                     CAS ID    Max Resp  Max Resp Rate  \
# 9408  CAS Negative Control   46.060377       9.707292
# 9409        CAS 12678-07-8   11.045211       0.108971
# 9410        CAS 10016-20-3   31.913605       7.093787
# 9411         CAS 7585-39-9   50.362171      13.499337
# 9412        CAS 17465-86-0   34.328790       7.268642
# ...                    ...         ...            ...
# 9595          CAS 333-93-7   22.597935       2.251771
# 9596           CAS 96-26-4  144.589180      18.709067
# 9597          CAS 513-85-9   11.510950       0.396986
# 9598          CAS 431-03-8   46.877619       2.399350
# 9599          CAS 513-86-0   44.866818       9.705050
#
#       Time till max resp rate          AUC  Growth  Control Well Growth_x  \
# 9408                    15.25  1465.665034       0                      0
# 9409                    20.25   528.332450       0                      0
# 9410                    42.25  1330.442581       0                      0
# 9411                    40.75  2060.766690       0                      0
# 9412                    39.50  1477.977658       0                      0
# ...                       ...          ...     ...                    ...
# 9595                    31.50   938.331383       0                      0
# 9596                    27.75  6326.319655       1                      0
# 9597                     3.50   530.771989       0                      0
# 9598                    48.00  1466.610326       0                      0
# 9599                    26.75  1995.851775       0                      0
#
#       Control Well Growth_y
# 9408                      0
# 9409                      0
# 9410                      0
# 9411                      0
# 9412                      0
# ...                     ...
# 9595                      0
# 9596                      0
# 9597                      0
# 9598                      0
# 9599                      0
#
# [192 rows x 18 columns]

# %%
kinetics[(kinetics['Strain']=='BW25113')&(kinetics['Plate']=='PM02A')]
# Out:
#      PlateIDs   Strain  Specie Well  Plate         Media Replicates  \
# 9120    ECP95  BW25113  E.Coli  A01  PM02A  M9 No Carbon         R1
# 9121    ECP95  BW25113  E.Coli  A02  PM02A  M9 No Carbon         R1
# 9122    ECP95  BW25113  E.Coli  A03  PM02A  M9 No Carbon         R1
# 9123    ECP95  BW25113  E.Coli  A04  PM02A  M9 No Carbon         R1
# 9124    ECP95  BW25113  E.Coli  A05  PM02A  M9 No Carbon         R1
# ...       ...      ...     ...  ...    ...           ...        ...
# 9403    ECP97  BW25113  E.Coli  H08  PM02A  M9 No Carbon         R2
# 9404    ECP97  BW25113  E.Coli  H09  PM02A  M9 No Carbon         R2
# 9405    ECP97  BW25113  E.Coli  H10  PM02A  M9 No Carbon         R2
# 9406    ECP97  BW25113  E.Coli  H11  PM02A  M9 No Carbon         R2
# 9407    ECP97  BW25113  E.Coli  H12  PM02A  M9 No Carbon         R2
#
#                    Compound                 Description KEGG ID  \
# 9120       Negative Control  C-Source, negative control     NaN
# 9121  Chondroitin Sulfate C           C-Source, polymer  C00635
# 9122         a-Cyclodextrin           C-Source, polymer  C00973
# 9123         b-Cyclodextrin           C-Source, polymer     NaN
# 9124         g-Cyclodextrin           C-Source, polymer     NaN
# ...                     ...                         ...     ...
# 9403             Putrescine             C-Source, amine  C00134
# 9404       Dihydroxyacetone           C-Source, alcohol  C00184
# 9405         2,3-Butanediol           C-Source, alcohol  C03044
# 9406        2,3-Butanedione           C-Source, alcohol  C00741
# 9407   3-Hydroxy-2-butanone           C-Source, alcohol  C00466
#
#                     CAS ID    Max Resp  Max Resp Rate  \
# 9120  CAS Negative Control   55.987643      13.111592
# 9121        CAS 12678-07-8   58.568321      17.119765
# 9122        CAS 10016-20-3   59.382592      15.831784
# 9123         CAS 7585-39-9   59.341615      18.073161
# 9124        CAS 17465-86-0   63.238180      22.134679
# ...                    ...         ...            ...
# 9403          CAS 333-93-7   70.075397      21.683180
# 9404           CAS 96-26-4  161.730653      21.706441
# 9405          CAS 513-85-9   38.403854      10.609858
# 9406          CAS 431-03-8   50.412269      12.515136
# 9407          CAS 513-86-0   69.427082      19.525911
#
#       Time till max resp rate          AUC  Growth  Control Well Growth_x  \
# 9120                    48.00  2268.892834       0                      0
# 9121                    48.00  2469.529799       0                      0
# 9122                    48.00  2404.537359       0                      0
# 9123                    48.00  2532.121238       0                      0
# 9124                     6.50  2608.258711       0                      0
# ...                       ...          ...     ...                    ...
# 9403                    48.00  2971.021055       0                      0
# 9404                    24.75  7153.868101       1                      0
# 9405                    45.75  1701.138448       0                      0
# 9406                    46.25  2097.936352       0                      0
# 9407                    45.50  3171.479453       0                      0
#
#       Control Well Growth_y
# 9120                      0
# 9121                      0
# 9122                      0
# 9123                      0
# 9124                      0
# ...                     ...
# 9403                      0
# 9404                      0
# 9405                      0
# 9406                      0
# 9407                      0
#
# [192 rows x 18 columns]
